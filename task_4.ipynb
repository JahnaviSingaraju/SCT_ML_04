# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

train_df = pd.read_csv("/content/sign_mnist_train[1].csv")
test_df = pd.read_csv("/content/sign_mnist_test[1].csv")

X_train = train_df.drop("label", axis=1).values / 255.0
y_train = train_df["label"].values
X_test = test_df.drop("label", axis=1).values / 255.0
y_test = test_df["label"].values

X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

num_classes = np.max(y_train) + 1
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(28,28,1)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, y_train_cat, epochs=10, validation_data=(X_test, y_test_cat), batch_size=64)

loss, acc = model.evaluate(X_test, y_test_cat, verbose=0)
print(f"Test Accuracy: {acc * 100:.2f}%")

y_pred_probs = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
print(classification_report(y_test, y_pred_classes))

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

plt.figure(figsize=(9,9))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap="gray")
    plt.title(f"T:{y_test[i]} P:{y_pred_classes[i]}")
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.2642 - loss: 2.4558 - val_accuracy: 0.7821 - val_loss: 0.7107
# Epoch 2/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.7724 - loss: 0.6879 - val_accuracy: 0.8579 - val_loss: 0.4446
# Epoch 3/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 41s 57ms/step - accuracy: 0.8732 - loss: 0.3761 - val_accuracy: 0.8837 - val_loss: 0.3828
# Epoch 4/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.9177 - loss: 0.2380 - val_accuracy: 0.9011 - val_loss: 0.3751
# Epoch 5/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 25s 59ms/step - accuracy: 0.9408 - loss: 0.1709 - val_accuracy: 0.9011 - val_loss: 0.3231
# Epoch 6/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.9540 - loss: 0.1326 - val_accuracy: 0.9080 - val_loss: 0.3530
# Epoch 7/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.9585 - loss: 0.1222 - val_accuracy: 0.9099 - val_loss: 0.3467
# Epoch 8/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 42s 58ms/step - accuracy: 0.9641 - loss: 0.1021 - val_accuracy: 0.9081 - val_loss: 0.3917
# Epoch 9/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.9663 - loss: 0.0895 - val_accuracy: 0.9096 - val_loss: 0.4513
# Epoch 10/10
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.9727 - loss: 0.0775 - val_accuracy: 0.9155 - val_loss: 0.3510
# Test Accuracy: 91.55%
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92       331
#            1       1.00      1.00      1.00       432
#            2       1.00      1.00      1.00       310
#            3       0.94      1.00      0.97       245
#            4       0.92      0.89      0.91       498
#            5       1.00      1.00      1.00       247
#            6       0.94      0.90      0.92       348
#            7       0.96      0.91      0.93       436
#            8       0.86      0.85      0.86       288
#           10       0.99      0.91      0.95       331
#           11       0.91      1.00      0.95       209
#           12       0.94      0.90      0.92       394
#           13       1.00      0.69      0.82       291
#           14       1.00      1.00      1.00       246
#           15       0.93      1.00      0.96       347
#           16       0.87      1.00      0.93       164
#           17       0.82      0.59      0.69       144
#           18       0.75      0.92      0.83       246
#           19       0.84      0.67      0.74       248
#           20       0.83      0.87      0.85       266
#           21       0.89      1.00      0.94       346
#           22       1.00      0.90      0.95       206
#           23       0.83      0.97      0.89       267
#           24       0.86      0.86      0.86       332
#
#     accuracy                           0.92      7172
#    macro avg       0.91      0.91      0.91      7172
# weighted avg       0.92      0.92      0.91      7172
